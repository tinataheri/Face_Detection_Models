# %%
import cv2
import numpy as np
import imutils
import matplotlib.pyplot as plt
import os

# %%
# !wget -N 'https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml'
# !wget -N 'https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_eye.xml'
# !wget -N 'https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_smile.xml'
# Out:
# --2021-09-02 08:59:51--  https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal     [ <=>                ]   8.29M  --.-KB/s    in 0.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-09-02 08:59:54 (60.7 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [8690469]
#
# --2021-09-02 08:59:54--  https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haarcascade_eye.xml’
#
# ...

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

filename = '/content/drive/MyDrive/paper_face_recognitioin/FDDB-images/2002/08/31/big/img_18008.jpg'
image = cv2.imread(filename)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
print(faces)
for face in faces:
  x, y, width, height = face


for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+width, y+height), (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0f28ced149c3> in <module>()
# ----> 1 face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#       2
#       3 filename = '/content/drive/MyDrive/paper_face_recognitioin/FDDB-images/2002/08/31/big/img_18008.jpg'
#       4 image = cv2.imread(filename)
#       5 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#
# NameError: name 'cv2' is not defined
